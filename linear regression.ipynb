# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
x = np.random.randint(0,3,8)
y = np.random.randint(1,3,8)

# %%
x = np.random.normal(0,1,8) + np.arange(1,9)
y = np.random.normal(0,1,8) + np.linspace(0,2,8)
sns.regplot(x,y)

# %% [markdown]
# y = b0 + b1*x

# %%
X
